# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import sys

sys.path.append("../../utils")

from shannon import calc_coper
from adjust_molecule import get_bond_angle, adjust_bond_angle
from convert import ob_2_pyscf
# Out:
# /Users/jose/shannon_entropy/.venv/lib/python3.11/site-packages/pyscf/dft/libxc.py:771: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, corresponding to the original definition by Stephens et al. (issue 1480) and the same as the B3LYP functional in Gaussian. To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '

# %%
def plot_bond_angle(mol_name, angle_min, angle_max, num_points, idx_1=2, idx_2=1, idx_3=3, basis='sto-3g', xc='B3LYP'):
    x = np.linspace(angle_min, angle_max, num=num_points)
    y = np.zeros(len(x))

    for i in range(len(x)):
        print(i)
        mol_ob = adjust_bond_angle(mol_name, idx_1, idx_2, idx_3, x[i])
        y[i] = calc_coper(mol_ob, basis=basis, xc=xc)
        
    plt.xlabel("Bond angle (°)")
    plt.ylabel("CoPer")
    plt.axvline(x=get_bond_angle(mol_name, idx_1, idx_2, idx_3), color='r')
    plt.plot(x, y)
    plt.savefig(str.format("plots/bond_angle/{mol}_bondangle_{min}_{max}_{num}.png", mol=mol_name, min=angle_min, max=angle_max, num=num_points))
    plt.close()

# %%
plot_bond_angle(mol_name='CH4', angle_min=0.01, angle_max=180, num_points=1000)
# Out:
# 0
# /Users/jose/shannon_entropy/.venv/lib/python3.11/site-packages/openbabel/__init__.py:26: UserWarning: "import openbabel" is deprecated, instead use "from openbabel import openbabel"
#   warnings.warn('"import openbabel" is deprecated, instead use "from openbabel import openbabel"')
# SCF not converged.
# SCF energy = 2734.67819175906
# 1
# converged SCF energy = 104.926611647715
# 2
# converged SCF energy = 33.9099529590323
# 3
# converged SCF energy = 9.37791827260397
# 4
# converged SCF energy = -3.05575930574688
# 5
# converged SCF energy = -10.5703514762458
# 6
# converged SCF energy = -15.6028181429209
# 7
# converged SCF energy = -19.2085254762175
# 8
# converged SCF energy = -21.9187925780177
# 9
# converged SCF energy = -24.0302442566783
# 10
# converged SCF energy = -25.7215104621413
# 11
# converged SCF energy = -27.1065911957235
# 12
# converged SCF energy = -28.2616615983839
# 13
# converged SCF energy = -29.2395581446907
# 14
# ...

# %% [markdown]
# Plot BH<sub>3</sub>, CH<sub>4</sub>, NH<sub>3</sub>, H<sub>2</sub>O,  bond angles (symmetric)

# %%
mols = ['BH3', 'H2O', 'NH3', 'CH4']
for mol in mols:
    plot_bond_angle(mol, angle_min=0.01, angle_max=180, num_points=1000)
# Out:
# 0
# SCF not converged.
# SCF energy = 2494.83834330364
# 1
# converged SCF energy = 107.68000093821
# 2
# converged SCF energy = 42.0156505971949
# 3
# converged SCF energy = 19.3312084009658
# 4
# converged SCF energy = 7.83384937849516
# 5
# converged SCF energy = 0.885165224070711
# 6
# converged SCF energy = -3.7682678856874
# 7
# converged SCF energy = -7.10234352113318
# 8
# converged SCF energy = -9.60837367376454
# 9
# converged SCF energy = -11.5606489480514
# 10
# converged SCF energy = -13.1243500604285
# 11
# converged SCF energy = -14.4048940427011
# 12
# converged SCF energy = -15.4727210525273
# 13
# converged SCF energy = -16.376689931436
# 14
# converged SCF energy = -17.1517553455714
# 15
# converged SCF energy = -17.8235853764437
# 16
# converged SCF energy = -18.4114535929589
# 17
# converged SCF energy = -18.9301136963368
# 18
# converged SCF energy = -19.3910511493085
# 19
# converged SCF energy = -19.8033407193273
# 20
# ...
